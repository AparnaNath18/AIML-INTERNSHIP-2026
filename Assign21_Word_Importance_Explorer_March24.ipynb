# %%
# Import libraries
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd

# Sample documents
documents = [
    "Artificial intelligence improves automation in industries",
    "Machine learning is a branch of artificial intelligence",
    "Deep learning uses neural networks for predictions",
    "Artificial intelligence and data science are related fields",
    "Neural networks are widely used in machine learning applications"
]

# TF-IDF Vectorizer
vectorizer = TfidfVectorizer()

# Transform documents
tfidf_matrix = vectorizer.fit_transform(documents)

# Get feature names
feature_names = vectorizer.get_feature_names_out()

# Convert to dataframe
df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

print("TF-IDF Matrix:\n")
print(df)

# Display top keywords for each document
print("\nTop Keywords:\n")

for i, row in df.iterrows():
    top_words = row.sort_values(ascending=False).head(3)
    print(f"Document {i+1}:")
    print(top_words)
    print()
# Out:
# TF-IDF Matrix:
#
#         and  applications      are  artificial  automation    branch  \
# 0  0.000000      0.000000  0.00000    0.314037    0.468913  0.000000
# 1  0.000000      0.000000  0.00000    0.299610    0.000000  0.447372
# 2  0.000000      0.000000  0.00000    0.000000    0.000000  0.000000
# 3  0.390794      0.000000  0.31529    0.261719    0.000000  0.000000
# 4  0.000000      0.386245  0.31162    0.000000    0.000000  0.000000
#
#        data      deep    fields       for  ...   machine  networks    neural  \
# 0  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  ...  0.360937  0.000000  0.000000
# 2  0.000000  0.417016  0.000000  0.417016  ...  0.000000  0.336446  0.336446
# 3  0.390794  0.000000  0.390794  0.000000  ...  0.000000  0.000000  0.000000
# 4  0.000000  0.000000  0.000000  0.000000  ...  0.311620  0.311620  0.311620
#
# ...
